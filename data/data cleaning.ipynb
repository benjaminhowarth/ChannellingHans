# %%
import pandas as pd

# %%
df = pd.read_csv("GCI_CompleteData4.csv")

# %%
df.size
# Out:
# 30580

# %%
# df = df.loc[df['3rd_pillar_Macroeconomic_environment'] != None]
# df.size
missing = df[df['3rd_pillar_Macroeconomic_environment'].isnull()]
#.groupby(df['Country'])

# %%
missing['Country'].count
# Out:
# <bound method Series.count of 22                      Angola
# 23                      Angola
# 24                      Angola
# 27                      Angola
# 30                      Angola
# 31                      Angola
# 32                      Angola
# 118                   Barbados
# 120                   Barbados
# 132                     Belize
# 133                     Belize
# 134                     Belize
# 135                     Belize
# 137                     Belize
# 138                     Belize
# 139                     Belize
# 140                     Belize
# 141                     Belize
# 142                     Belize
# 150                      Benin
# 154                     Bhutan
# 155                     Bhutan
# 156                     Bhutan
# 157                     Bhutan
# 158                     Bhutan
# 159                     Bhutan
# 175                    Bolivia
# 183     Bosnia and Herzegovina
# 228               Burkina Faso
# ...

# %%
# Out:
#    Country  Year  1st_pillar_Institutions  2nd_pillar_Infrastructure  \
# 22  Angola  2007                      NaN                        NaN
# 23  Angola  2008                      NaN                        NaN
# 24  Angola  2009                      NaN                        NaN
# 27  Angola  2012                      NaN                        NaN
# 30  Angola  2015                      NaN                        NaN
#
#     3rd_pillar_Macroeconomic_environment  \
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 27                                   NaN
# 30                                   NaN
#
#     4th_pillar_Health_and_primary_education  \
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 27                                      NaN
# 30                                      NaN
#
# ...

# %%
df[df['3rd_pillar_Macroeconomic_environment'].isnull()]
# Out:
#                      Country  Year  1st_pillar_Institutions  \
# 22                    Angola  2007                      NaN
# 23                    Angola  2008                      NaN
# 24                    Angola  2009                      NaN
# 27                    Angola  2012                      NaN
# 30                    Angola  2015                      NaN
# 31                    Angola  2016                      NaN
# 32                    Angola  2017                      NaN
# 118                 Barbados  2015                      NaN
# 120                 Barbados  2017                      NaN
# 132                   Belize  2007                      NaN
# 133                   Belize  2008                      NaN
# 134                   Belize  2009                      NaN
# 135                   Belize  2010                      NaN
# 137                   Belize  2012                      NaN
# 138                   Belize  2013                      NaN
# ...

# %%
angola = df[df['Country']=='Angola']

# %%
minValue= None

for i in range(2007,2017):
    if angola[angola['Year']==i]['1st_pillar_Institutions'] ==Nan:
# Out:
#    Country  Year  1st_pillar_Institutions  2nd_pillar_Infrastructure  \
# 22  Angola  2007                      NaN                        NaN
# 23  Angola  2008                      NaN                        NaN
# 24  Angola  2009                      NaN                        NaN
# 25  Angola  2010                 3.219175                   1.881551
# 26  Angola  2011                 2.906737                   1.887377
# 27  Angola  2012                      NaN                        NaN
# 28  Angola  2013                 2.759893                   1.920763
# 29  Angola  2014                 2.606999                   2.014314
# 30  Angola  2015                      NaN                        NaN
# 31  Angola  2016                      NaN                        NaN
# 32  Angola  2017                      NaN                        NaN
#
#     3rd_pillar_Macroeconomic_environment  \
# 22                                   NaN
# 23                                   NaN
# ...

# %%
angola[angola['Year']==2007]['1st_pillar_Institutions']
# Out:
# 22   NaN
# Name: 1st_pillar_Institutions, dtype: float64
