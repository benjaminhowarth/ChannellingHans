# %%
import pandas as pd

# %%
df = pd.read_csv("GCI_CompleteData4.csv")
# df[df['Country']=='Angola']

# %%
df.loc[(df['Country']=='Angola') & (df["Year"] == 2010),'1st_pillar_Institutions']=float(df.loc[(df['Country']=='Angola') & (df["Year"] == 2011)]['1st_pillar_Institutions'])

df[df['Country']=='Angola']
# Out:
#    Country  Year  1st_pillar_Institutions  2nd_pillar_Infrastructure  \
# 22  Angola  2007                      NaN                        NaN
# 23  Angola  2008                      NaN                        NaN
# 24  Angola  2009                      NaN                        NaN
# 25  Angola  2010                 2.906737                   1.881551
# 26  Angola  2011                 2.906737                   1.887377
# 27  Angola  2012                      NaN                        NaN
# 28  Angola  2013                 2.759893                   1.920763
# 29  Angola  2014                 2.606999                   2.014314
# 30  Angola  2015                      NaN                        NaN
# 31  Angola  2016                      NaN                        NaN
# 32  Angola  2017                      NaN                        NaN
#
#     3rd_pillar_Macroeconomic_environment  \
# 22                                   NaN
# 23                                   NaN
# ...

# %%
# df = df.loc[df['3rd_pillar_Macroeconomic_environment'] != None]
# df.size
missing = df[df['3rd_pillar_Macroeconomic_environment'].isnull()]
#.groupby(df['Country'])

# %%
mylist = missing['Country'].unique()

# %%
df = pd.read_csv("GCI_CompleteData4.csv")
df[df['Country']=='Angola'].head(6)
print(missing['Country'].unique().size)
# Out:
# 31

# %%
counter=0
# while(df['1st_pillar_Institutions'].isnull().any()):
    
for country in mylist:
    counter+=1
    print(counter,'/31')
    for i in range(2007,2016):

        if df[df['Country']==country][ df['Year']==i]['Global_Competitiveness_Index'].isnull().any() == True:
            print(country, i)
            df.loc[(df['Country']==country) & (df["Year"] == i),'1st_pillar_Institutions']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['1st_pillar_Institutions'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'2nd_pillar_Infrastructure']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['2nd_pillar_Infrastructure'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'3rd_pillar_Macroeconomic_environment']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['3rd_pillar_Macroeconomic_environment'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'4th_pillar_Health_and_primary_education']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['4th_pillar_Health_and_primary_education'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'5th_pillar_Higher_education_and_training']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['5th_pillar_Higher_education_and_training'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'6th_pillar_Goods_market_efficiency']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['6th_pillar_Goods_market_efficiency'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'7th_pillar_Labor_market_efficiency']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['7th_pillar_Labor_market_efficiency'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'8th_pillar_Financial_market_development']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['8th_pillar_Financial_market_development'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'9th_pillar_Technological_readiness']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['9th_pillar_Technological_readiness'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'10th_pillar_Market_size']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['10th_pillar_Market_size'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'11th_pillar_Business_sophistication_']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['11th_pillar_Business_sophistication_'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'12th_pillar_Innovation']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['12th_pillar_Innovation'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'Global_Competitiveness_Index']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['Global_Competitiveness_Index'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'GDP']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['GDP'])
# Out:
# 1 /31
# Angola 2015
# 2 /31
# 3 /31
# Belize 2012
# /Users/benjaminhowarth/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# Belize 2013
# Belize 2014
# Belize 2015
# 4 /31
# 5 /31
# 6 /31
# 7 /31
# 8 /31
# Burkina Faso 2015
# 9 /31
# 10 /31
# 11 /31
# 12 /31
# 13 /31
# 14 /31
# 15 /31
# 16 /31
# 17 /31
# 18 /31
# 19 /31
# Libya 2015
# 20 /31
# 21 /31
# 22 /31
# 23 /31
# 24 /31
# 25 /31
# Suriname 2015
# 26 /31
# 27 /31
# Syria 2012
# Syria 2013
# Syria 2014
# Syria 2015
# 28 /31
# 29 /31
# 30 /31
# 31 /31

# %%
for country in mylist:
    counter+=1
    print(counter,'/31')    
    
    for i in range(2017,2008,-1):

        if df[df['Country']==country][ df['Year']==i]['Global_Competitiveness_Index'].isnull().any() == True:
            print(country)
            df.loc[(df['Country']==country) & (df["Year"] == i),'1st_pillar_Institutions']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['1st_pillar_Institutions'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'2nd_pillar_Infrastructure']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['2nd_pillar_Infrastructure'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'3rd_pillar_Macroeconomic_environment']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['3rd_pillar_Macroeconomic_environment'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'4th_pillar_Health_and_primary_education']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['4th_pillar_Health_and_primary_education'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'5th_pillar_Higher_education_and_training']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['5th_pillar_Higher_education_and_training'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'6th_pillar_Goods_market_efficiency']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['6th_pillar_Goods_market_efficiency'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'7th_pillar_Labor_market_efficiency']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['7th_pillar_Labor_market_efficiency'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'8th_pillar_Financial_market_development']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['8th_pillar_Financial_market_development'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'9th_pillar_Technological_readiness']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['9th_pillar_Technological_readiness'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'10th_pillar_Market_size']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['10th_pillar_Market_size'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'11th_pillar_Business_sophistication_']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['11th_pillar_Business_sophistication_'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'12th_pillar_Innovation']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['12th_pillar_Innovation'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'Global_Competitiveness_Index']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['Global_Competitiveness_Index'])
            df.loc[(df['Country']==country) & (df["Year"] == i),'GDP']=float(df.loc[(df['Country']==country) & (df["Year"] == i-1)]['GDP'])
# Out:
# 311 /31
# 312 /31
# 313 /31
# 314 /31
# 315 /31
# 316 /31
# 317 /31
# 318 /31
# 319 /31
# 320
# /Users/benjaminhowarth/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /31
# 321 /31
# 322 /31
# 323 /31
# 324 /31
# 325 /31
# 326 /31
# 327 /31
# 328 /31
# 329 /31
# 330 /31
# 331 /31
# 332 /31
# 333 /31
# 334 /31
# 335 /31
# 336 /31
# 337 /31
# 338 /31
# 339 /31
# 340 /31
# 341 /31

# %%
df.to_csv("GCI_CompleteData4_interpolated.csv")

# %%
# df[df['Country']=='Angola']
for country in mylist:
    for i in range(2017,2008,-1):
        print(i)
        
        if df[df['Country']==country][ df['Year']==i]['1st_pillar_Institutions'].isnull().any() == True:
            print(country)
# Out:
# 2017
# Angola
# 2016
# Angola
# 2015
# Angola
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# Barbados
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# Belize
# 2016
# Belize
# 2015
# Belize
# 2014
# Belize
# 2013
# Belize
# 2012
# Belize
# 2011
# 2010
# 2009
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# /Users/benjaminhowarth/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Bolivia
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# Burkina Faso
# 2016
# Burkina Faso
# 2015
# Burkina Faso
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2017
# Gabon
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# ...

# %%
#df[df['3rd_pillar_Macroeconomic_environment'].isnull()]

# %%
# minValue= None

# for i in range(2007,2017):
#     if angola[angola['Year']==i]['1st_pillar_Institutions'] ==Nan:

# %%
#angola[angola['Year']==2007]
# for i in range(2007,2016):
#     print(float(df.loc[(df['Country']=='Albania') & (df["Year"] == i+1)]['1st_pillar_Institutions']))

# %%
for country in mylist:
    for i in range(2007,2016):
        if df[df['Country']==country][ df['Year']==i]['1st_pillar_Institutions'].isnull().any:
            df.loc[(df['Country']==country) & (df["Year"] == i),'1st_pillar_Institutions']=float(df.loc[(df['Country']==country) & (df["Year"] == i+1)]['1st_pillar_Institutions'])

# %%
df.loc[(df['Country']=='Albania') & (df["Year"] == i)]['1st_pillar_Institutions']

# %%
df[df['Country']=='Angola']

# %%
df.Year.dtype

df.loc[df['Country']=='Albania'].Year[0]

# %%
df.loc[(df['Country']=='Albania') & (df["Year"] == df.loc[df['Country']=='Albania'].Year[0])]

# %%
df.loc[(df['Country']=='Albania') & (df["Year"] == 2007),'1st_pillar_Institutions']=2

# %%
#df.loc[(df['column_name'] == some_value) & df['other_column'].isin(some_values)]
df.loc[(df['Country']=='Albania') & (df["Year"] == 2007)]['1st_pillar_Institutions']

# %%
df.loc[df['Country']=='Angola']

# %%
df[df['Country']=='Angola'][ df['Year']==2007] ['1st_pillar_Institutions']=10

# %%
df[df['Country']=='Angola'][ df['Year']==2007] ['1st_pillar_Institutions']
